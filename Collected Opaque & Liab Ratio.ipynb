# %%
import pickle
import pandas as pd
import numpy as np

# %%
file = pd.read_csv("opaque_index.csv",index_col=0)

# %%
List = pd.read_fwf('DemoList.txt')

# %%
text=pd.DataFrame()
for name in List.values.tolist():
    try:
        text=pd.concat([text,file.loc[name]])
    except:
        continue

# %%
text
# Out:
#             time    opaque
# ELON  12/31/2000  0.084109
# ELON   3/31/2001  0.076997
# ELON   6/30/2001  0.066354
# ELON   9/30/2001  0.058035
# ELON  12/31/2001  0.063293
# ELON   3/31/2002  0.065486
# ELON   6/30/2002  0.064256
# ELON   9/30/2002  0.063635
# ELON  12/31/2002  0.067651
# ELON   3/31/2003  0.066179
# ELON   6/30/2003  0.058845
# ELON   9/30/2003  0.051246
# ELON  12/31/2003  0.053618
# ELON   3/31/2004  0.052991
# ELON   6/30/2004  0.050903
# ELON   9/30/2004  0.045498
# ELON  12/31/2004  0.033580
# ELON   3/31/2005  0.031384
# ELON   6/30/2005  0.032688
# ELON   9/30/2005  0.037620
# ELON  12/31/2005  0.034997
# ELON   3/31/2006  0.034598
# ELON   6/30/2006  0.032328
# ELON   9/30/2006  0.026598
# ELON  12/31/2006  0.020453
# ELON   3/31/2007  0.022125
# ELON   6/30/2007  0.022325
# ELON   9/30/2007  0.023829
# ELON  12/31/2007  0.024947
# ELON   3/31/2008  0.024158
# ...          ...       ...
# VIAV  12/31/2011  0.101331
# VIAV   3/31/2012  0.065280
# ...

# %%
file2 = pd.read_csv("LiabRatio.csv",index_col = 3)
ratio = pd.read_fwf('DemoList.txt')
ratiolist=pd.DataFrame()
for tic in ratio.values.tolist():
    try:
        ratiolist = pd.concat([ratiolist, file2.loc[tic]])
    except:
        continue

# %%
ratiolist #負債比
# Out:
#         datadate  fyearq  fqtr datacqtr datafqtr     Asset  Liability
# tic
# ELON   3/31/1996    1996     1   1996Q1   1996Q1       NaN        NaN
# ELON   6/30/1996    1996     2   1996Q2   1996Q2       NaN        NaN
# ELON   9/30/1996    1996     3   1996Q3   1996Q3       NaN        NaN
# ELON  12/31/1996    1996     4   1996Q4   1996Q4    15.855      8.717
# ELON   3/31/1997    1997     1   1997Q1   1997Q1       NaN        NaN
# ELON   6/30/1997    1997     2   1997Q2   1997Q2       NaN        NaN
# ELON   9/30/1997    1997     3   1997Q3   1997Q3       NaN        NaN
# ELON  12/31/1997    1997     4   1997Q4   1997Q4    16.816      8.016
# ELON   3/31/1998    1998     1   1998Q1   1998Q1    15.695      8.213
# ELON   6/30/1998    1998     2   1998Q2   1998Q2    14.386      7.920
# ELON   9/30/1998    1998     3   1998Q3   1998Q3    43.968      7.088
# ELON  12/31/1998    1998     4   1998Q4   1998Q4    41.950      6.164
# ...
